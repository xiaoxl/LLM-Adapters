# %%
import pandas as pd

damage_dev = pd.read_csv('crisismmd_datasplit_all/task_damage_text_img_dev.tsv', sep='\t')
damage_test = pd.read_csv('crisismmd_datasplit_all/task_damage_text_img_test.tsv', sep='\t')
damage_train = pd.read_csv('crisismmd_datasplit_all/task_damage_text_img_train.tsv', sep='\t')

humanitarian_dev = pd.read_csv('crisismmd_datasplit_all/task_humanitarian_text_img_dev.tsv', sep='\t')
humanitarian_test = pd.read_csv('crisismmd_datasplit_all/task_humanitarian_text_img_test.tsv', sep='\t')
humanitarian_train = pd.read_csv('crisismmd_datasplit_all/task_humanitarian_text_img_train.tsv', sep='\t')

informative_dev = pd.read_csv('crisismmd_datasplit_all/task_informative_text_img_dev.tsv', sep='\t')
informative_test = pd.read_csv('crisismmd_datasplit_all/task_informative_text_img_test.tsv', sep='\t')
informative_train = pd.read_csv('crisismmd_datasplit_all/task_informative_text_img_train.tsv', sep='\t')

# %%
informative_dev
# Out:
#                 event_name            tweet_id              image_id  \
# 0     iraq_iran_earthquake  931465546129989632  931465546129989632_0
# 1         hurricane_harvey  905064623199719425  905064623199719425_0
# 2          hurricane_maria  922857566220283904  922857566220283904_0
# 3           hurricane_irma  909767231411769344  909767231411769344_0
# 4     california_wildfires  920571592131915777  920571592131915777_0
# ...                    ...                 ...                   ...
# 2232       hurricane_maria  921842963843551233  921842963843551233_0
# 2233     mexico_earthquake  910658635851644928  910658635851644928_0
# 2234      hurricane_harvey  906341151061499910  906341151061499910_0
# 2235       hurricane_maria  928822277067636737  928822277067636737_0
# 2236       hurricane_maria  913401831031820288  913401831031820288_0
#
#                                              tweet_text  \
# 0     #Iran #earthquake damage put at over 5bn pound...
# ...
